# %%
import csv
from faker import Faker
fake=Faker('en_IN')
methods={
    'uid':lambda:'IQ-'+"".join(random.choices(string.digits+string.ascii_uppercase,k=5),
    'first_name':fake.first_name,
    'last_name':fake.last_name,
    'email':fake:email,
    'phone_number':fake.phone_number,
    'city':fake.city,
    'state':fake.state,
    'country':fake.country,
    'random_number':fake.random_number,
    'date':fake.date_time,
    'salary':lambda:random.randrange(200000,1000000)
}
def create_csv_data():
    print("------------Creating Csv Dataset--------------")
    file_name=input("Enter your file name without extension")+".csv"
    try:
        num_rows=int(input("Enter number of rows :"))
        if num_rows<=0:
            raise ValueError
        except ValueError as e: 
            print("

# %%
from faker import Faker
import pandas as pd

# Initialize Faker
fake = Faker()
fake=Faker('en_IN')

# Number of rows to generate
num_rows = 100

# Create a list to store the data
data = []

# Generate fake data
for _ in range(num_rows):
    row = {
        "Name": fake.name(),
        "Email": fake.email(),
        "Phone Number": fake.phone_number(),
        "Address": fake.address(),
        "City": fake.city(),
        "State": fake.state(),
        "Postal Code": fake.postcode(),
        "Company": fake.company(),
        "Job Title": fake.job(),
        "Date of Birth": fake.date_of_birth(minimum_age=18, maximum_age=65),
        "Registration Date": fake.date_this_year(),
    }
    data.append(row)

# Convert to DataFrame
df = pd.DataFrame(data)

# Save to CSV (optional)
df.to_csv("fake_dataset.csv", index=False)

# Print the dataset
df
# Out:
#                  Name                     Email   Phone Number  \
# 0       Zayyan Butala        tgoyal@example.net  +915516477348
# 1        Faraj Cheema       dipta60@example.com     7591850052
# 2   Vasatika Deshmukh         zdash@example.com  +913021017676
# 3         Tarak Soman  srinivassara@example.com    03342808276
# 4      Daksha Agrawal     kabirdeol@example.com  +915218558311
# ..                ...                       ...            ...
# 95    Aarnav Raghavan   trivediamol@example.org     8029353301
# 96         Qabil Dhar         cvala@example.net  +917473409665
# 97       Manthan Bhat      darpan16@example.org     4325569048
# 98    Gaurav Tripathi   widisharout@example.org    01068277828
# 99         Irya Yadav         ygour@example.org     7558426303
#
#                                       Address            City  \
# 0              84\nSetty Ganj\nAligarh-368999    North Dumdum
# 1            87, Sampath Street\nAjmer 894249        Ludhiana
# ...

# %%
from faker import Faker
import pandas as pd

# Initialize Faker
fake = Faker()

# Number of rows to generate
num_rows = 100

# Create a list to store the data
data = []

# Generate fake data
for _ in range(num_rows):
    row = {
        "Name": fake.name(),
        "Email": fake.email(),
        "Phone Number": fake.phone_number(),
        "Address": fake.address(),
        "City": fake.city(),
        "State": fake.state(),
        "Country": fake.country(),
        "Postal Code": fake.postcode(),
        "Company": fake.company(),
        "Job Title": fake.job(),
        "Date of Birth": fake.date_of_birth(minimum_age=18, maximum_age=65),
        "Registration Date": fake.date_this_year(),
    }
    data.append(row)

# Convert to DataFrame
df = pd.DataFrame(data)

# Save to Excel
df.to_excel("fake_dataset.xlsx", index=False)

# Print confirmation message
print("Dataset saved as 'fake_dataset.xlsx'")
# Out:
# Dataset saved as 'fake_dataset.xlsx'
